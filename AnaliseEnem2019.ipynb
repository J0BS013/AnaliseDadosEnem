# %% [markdown]
# ## Explorando dados

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('https://github.com/alura-cursos/imersao-dados-2-2020/blob/master/MICRODADOS_ENEM_2019_SAMPLE_43278.csv?raw=true')

df.head()
# Out:
#    NU_INSCRICAO  NU_ANO  CO_MUNICIPIO_RESIDENCIA  ... Q023  Q024 Q025
# 0  190001004661    2019                  1506138  ...    A     B    B
# 1  190001004674    2019                  1504208  ...    A     A    B
# 2  190001004722    2019                  1501402  ...    A     A    B
# 3  190001004735    2019                  1507300  ...    A     A    B
# 4  190001004776    2019                  1500800  ...    A     A    B
#
# [5 rows x 136 columns]

# %%
#Tamanho dataset

df.shape
# Out:
# (127380, 136)

# %%
df['SG_UF_RESIDENCIA']
# Out:
# 0         PA
# 1         PA
# 2         PA
# 3         PA
# 4         PA
#           ..
# 127375    MG
# 127376    BA
# 127377    BA
# 127378    BA
# 127379    MG
# Name: SG_UF_RESIDENCIA, Length: 127380, dtype: object

# %%
df.columns.values
# Out:
# array(['NU_INSCRICAO', 'NU_ANO', 'CO_MUNICIPIO_RESIDENCIA',
#        'NO_MUNICIPIO_RESIDENCIA', 'CO_UF_RESIDENCIA', 'SG_UF_RESIDENCIA',
#        'NU_IDADE', 'TP_SEXO', 'TP_ESTADO_CIVIL', 'TP_COR_RACA',
#        'TP_NACIONALIDADE', 'CO_MUNICIPIO_NASCIMENTO',
#        'NO_MUNICIPIO_NASCIMENTO', 'CO_UF_NASCIMENTO', 'SG_UF_NASCIMENTO',
#        'TP_ST_CONCLUSAO', 'TP_ANO_CONCLUIU', 'TP_ESCOLA', 'TP_ENSINO',
#        'IN_TREINEIRO', 'CO_ESCOLA', 'CO_MUNICIPIO_ESC',
#        'NO_MUNICIPIO_ESC', 'CO_UF_ESC', 'SG_UF_ESC',
#        'TP_DEPENDENCIA_ADM_ESC', 'TP_LOCALIZACAO_ESC', 'TP_SIT_FUNC_ESC',
#        'IN_BAIXA_VISAO', 'IN_CEGUEIRA', 'IN_SURDEZ',
#        'IN_DEFICIENCIA_AUDITIVA', 'IN_SURDO_CEGUEIRA',
#        'IN_DEFICIENCIA_FISICA', 'IN_DEFICIENCIA_MENTAL',
#        'IN_DEFICIT_ATENCAO', 'IN_DISLEXIA', 'IN_DISCALCULIA',
#        'IN_AUTISMO', 'IN_VISAO_MONOCULAR', 'IN_OUTRA_DEF', 'IN_GESTANTE',
#        'IN_LACTANTE', 'IN_IDOSO', 'IN_ESTUDA_CLASSE_HOSPITALAR',
#        'IN_SEM_RECURSO', 'IN_BRAILLE', 'IN_AMPLIADA_24', 'IN_AMPLIADA_18',
#        'IN_LEDOR', 'IN_ACESSO', 'IN_TRANSCRICAO', 'IN_LIBRAS',
#        'IN_TEMPO_ADICIONAL', 'IN_LEITURA_LABIAL', 'IN_MESA_CADEIRA_RODAS',
#        'IN_MESA_CADEIRA_SEPARADA', 'IN_APOIO_PERNA', 'IN_GUIA_INTERPRETE',
#        'IN_COMPUTADOR', 'IN_CADEIRA_ESPECIAL', 'IN_CADEIRA_CANHOTO',
#        'IN_CADEIRA_ACOLCHOADA', 'IN_PROVA_DEITADO', 'IN_MOBILIARIO_OBESO',
#        'IN_LAMINA_OVERLAY', 'IN_PROTETOR_AURICULAR', 'IN_MEDIDOR_GLICOSE',
#        'IN_MAQUINA_BRAILE', 'IN_SOROBAN', 'IN_MARCA_PASSO', 'IN_SONDA',
#        'IN_MEDICAMENTOS', 'IN_SALA_INDIVIDUAL', 'IN_SALA_ESPECIAL',
#        'IN_SALA_ACOMPANHANTE', 'IN_MOBILIARIO_ESPECIFICO',
#        'IN_MATERIAL_ESPECIFICO', 'IN_NOME_SOCIAL', 'CO_MUNICIPIO_PROVA',
#        'NO_MUNICIPIO_PROVA', 'CO_UF_PROVA', 'SG_UF_PROVA',
#        'TP_PRESENCA_CN', 'TP_PRESENCA_CH', 'TP_PRESENCA_LC',
#        'TP_PRESENCA_MT', 'CO_PROVA_CN', 'CO_PROVA_CH', 'CO_PROVA_LC',
#        'CO_PROVA_MT', 'NU_NOTA_CN', 'NU_NOTA_CH', 'NU_NOTA_LC',
#        'NU_NOTA_MT', 'TX_RESPOSTAS_CN', 'TX_RESPOSTAS_CH',
#        'TX_RESPOSTAS_LC', 'TX_RESPOSTAS_MT', 'TP_LINGUA',
#        'TX_GABARITO_CN', 'TX_GABARITO_CH', 'TX_GABARITO_LC',
#        'TX_GABARITO_MT', 'TP_STATUS_REDACAO', 'NU_NOTA_COMP1',
#        'NU_NOTA_COMP2', 'NU_NOTA_COMP3', 'NU_NOTA_COMP4', 'NU_NOTA_COMP5',
#        'NU_NOTA_REDACAO', 'Q001', 'Q002', 'Q003', 'Q004', 'Q005', 'Q006',
#        'Q007', 'Q008', 'Q009', 'Q010', 'Q011', 'Q012', 'Q013', 'Q014',
#        'Q015', 'Q016', 'Q017', 'Q018', 'Q019', 'Q020', 'Q021', 'Q022',
#        'Q023', 'Q024', 'Q025'], dtype=object)

# %%
df[['NU_INSCRICAO','Q025']]
# Out:
#         NU_INSCRICAO Q025
# 0       190001004661    B
# 1       190001004674    B
# 2       190001004722    B
# 3       190001004735    B
# 4       190001004776    B
# ...              ...  ...
# 127375  190006120035    B
# 127376  190006120036    B
# 127377  190006120037    B
# 127378  190006120060    A
# 127379  190006120170    B
#
# [127380 rows x 2 columns]

# %%
print(df['SG_UF_RESIDENCIA'].unique())

len(df['SG_UF_RESIDENCIA'].unique())
# Out:
# ['PA' 'RO' 'MT' 'AC' 'AM' 'RR' 'MA' 'PR' 'BA' 'PI' 'CE' 'PE' 'AP' 'TO'
#  'SC' 'GO' 'MG' 'SP' 'SE' 'RJ' 'PB' 'AL' 'RN' 'ES' 'DF' 'RS' 'MS']
# 27

# %%
df['SG_UF_RESIDENCIA'].value_counts()
# Out:
# SP    20264
# MG    13547
# BA    10040
# RJ     8467
# CE     7381
# PA     7170
# PE     6941
# MA     5543
# RS     5466
# PR     5259
# GO     4268
# PB     3690
# PI     3034
# RN     2959
# AM     2820
# SC     2673
# ES     2550
# DF     2408
# AL     2263
# MT     2230
# SE     1815
# MS     1655
# RO     1400
# TO     1178
# AP     1047
# AC      946
# RR      366
# Name: SG_UF_RESIDENCIA, dtype: int64

# %%
#Ordenação por index

df['NU_IDADE'].value_counts().sort_index()
# Out:
# 13        4
# 14      141
# 15     2009
# 16     7830
# 17    21256
#       ...
# 73        2
# 75        2
# 76        1
# 77        1
# 82        1
# Name: NU_IDADE, Length: 65, dtype: int64

# %% [markdown]
# ## Proporção de inscritos por idade

# %%
#mul() = multiplicar

proporcaoIdade = df['NU_IDADE'].value_counts(normalize=True).mul(100)
proporcaoIdade
# Out:
# 18    16.840948
# 17    16.687078
# 19    11.318888
# 20     8.174753
# 16     6.146962
#         ...
# 75     0.001570
# 73     0.001570
# 82     0.000785
# 77     0.000785
# 76     0.000785
# Name: NU_IDADE, Length: 65, dtype: float64

# %%
proporcaoIdade.plot.bar(figsize = (25,15), color = 'deepskyblue')
plt.title('Proporção de inscritos no ENEM por idade', fontsize='xx-large')
plt.xlabel('Idades', fontsize=15)
plt.ylabel('Proporção de inscritos', fontsize=15)
# Out:
# Text(0, 0.5, 'Proporção de inscritos')

# %%
#Quais os estados tem inscritos com 13 anos

df.query('NU_IDADE==13')['SG_UF_RESIDENCIA'].value_counts()
# Out:
# AP    1
# MT    1
# BA    1
# SP    1
# Name: SG_UF_RESIDENCIA, dtype: int64

# %%
#Gráfico com texto

plt.title('Distribuição de participações no ENEM por idade', fontsize='xx-large')
plt.xlabel('Idade', fontsize=12)
plt.ylabel('Número de participantes',fontsize=12)

df["NU_IDADE"].hist(bins=20, figsize = (10,8), color ='red')

# %% [markdown]
# ## Distribuição de treineiros

# %%
#Inscritos que são treineiros por idade

df.query("IN_TREINEIRO == 1")['NU_IDADE'].value_counts().sort_index()
# Out:
# 14      64
# 15    1927
# 16    7142
# 17    4901
# 18     858
# 19     228
# 20      83
# 21      44
# 22      30
# 23      21
# 24      13
# 25       8
# 26      13
# 27       9
# 28       6
# 29      10
# 30       4
# 31       4
# 32       2
# 33       1
# 34       3
# 35       2
# 36       2
# 37       1
# 38       4
# 39       2
# 40       4
# 41       1
# 42       4
# 44       2
# 45       1
# 46       2
# 47       1
# 48       1
# 51       1
# 55       1
# 62       1
# Name: NU_IDADE, dtype: int64

# %% [markdown]
# ## Histogramas das idades dos treineiros e não treineiros

# %%
TreineirosIdade = df.query("IN_TREINEIRO == 1")['NU_IDADE']

plt.title('Distribuição de idade dos treineiros', fontsize='xx-large')
plt.xlabel('Idade', fontsize=12)
plt.ylabel('Número de participantes',fontsize=12)

TreineirosIdade.hist(bins=30, figsize = (10,8))

# %%
TreineirosIdade = df.query("IN_TREINEIRO == 0")['NU_IDADE']

plt.title('Distribuição de idade dos não treineiros', fontsize='xx-large')
plt.xlabel('Idade', fontsize=12)
plt.ylabel('Número de participantes',fontsize=12)

TreineirosIdade.hist(bins=30, figsize = (10,8))

# %% [markdown]
# ## Explorando as Notas

# %%
df['NU_NOTA_REDACAO'].hist(bins=20, figsize = (12,8), color ='midnightblue')
plt.title('Distribuição das notas de redação por participantes', fontsize='xx-large')
plt.xlabel('Notas', fontsize = 12)
plt.ylabel('Participantes',fontsize=12)
# Out:
# Text(0, 0.5, 'Participantes')

# %%
df['NU_NOTA_LC'].hist(bins=20, figsize = (12,8), color ='midnightblue')
plt.title('Distribuição das notas de línguagens e códigos por participantes', fontsize='xx-large')
plt.xlabel('Notas', fontsize = 12)
plt.ylabel('Participantes',fontsize=12)
# Out:
# Text(0, 0.5, 'Participantes')

# %%
#Média das notas de redação

df['NU_NOTA_REDACAO'].mean()
# Out:
# 571.5700253970197

# %%
#Desvio padrão das notas de redação

df['NU_NOTA_REDACAO'].std()
# Out:
# 188.07645455749753

# %%
notas = ['NU_NOTA_REDACAO', 'NU_NOTA_CN', 'NU_NOTA_CH', 'NU_NOTA_MT', 'NU_NOTA_LC']

df[notas].describe()
# Out:
#        NU_NOTA_REDACAO    NU_NOTA_CN    NU_NOTA_CH    NU_NOTA_MT    NU_NOTA_LC
# count     98043.000000  92758.000000  98043.000000  92758.000000  98043.000000
# mean        571.570025    477.964015    507.365912    523.555206    520.463928
# std         188.076455     76.296099     82.972839    109.416939     64.556578
# min           0.000000      0.000000      0.000000      0.000000      0.000000
# 25%         480.000000    418.000000    447.900000    435.300000    483.700000
# 50%         580.000000    470.200000    510.900000    501.600000    526.100000
# 75%         680.000000    533.300000    567.100000    598.200000    565.100000
# max        1000.000000    797.300000    809.400000    985.000000    801.700000

# %%
df['NU_NOTA_REDACAO'].plot.box(grid = True, figsize = (10,8))
plt.title('Distribuição das notas de redação por participantes', fontsize='xx-large')
plt.ylabel('Notas participantes',fontsize=12)
# Out:
# Text(0, 0.5, 'Notas participantes')

# %%
df[notas].boxplot(grid = True, figsize = (10,8))
plt.title('Distribuição das notas por participantes', fontsize='xx-large')
plt.ylabel('Notas participantes',fontsize=12)
# Out:
# Text(0, 0.5, 'Notas participantes')

# %% [markdown]
# ## Desafio: Direfenças na escolha de linguagem na prova de Linguagens e Códigos

# %%
#Comparando disparidade das provas de Inglês e espanhol

espanhol = df.query('TP_LINGUA == 1')['NU_NOTA_LC']

ingles = df.query('TP_LINGUA == 0')['NU_NOTA_LC']

plt.title('Disparidade de notas das provas de Inglês e espanhol', fontsize='xx-large')
plt.xlabel('Notas', fontsize = 12)
plt.ylabel('Participantes',fontsize=12)

ingles.hist(bins=20, figsize = (10,8), label = 'Inglês',) 
espanhol.hist(bins=20, figsize = (10,8), label = 'Espanhol', alpha = 0.7)
plt.legend()

# %% [markdown]
# ## Análise de Dados SocioEconômicos

# %%
import seaborn as sns

# %%
renda_ordenada = df['Q006'].unique()
renda_ordenada.sort()

plt.figure(figsize=(10,6))
plt.title("Notas de matemática por renda familiar")
sns.boxplot(x = 'Q006', y = 'NU_NOTA_MT', data = df, order = renda_ordenada)

# %%
#axis1 = linha
#axis0 = linha

df['NU_NOTA_TOTAL'] = df[notas].sum(axis=1)
df.head()
# Out:
#    NU_INSCRICAO  NU_ANO  CO_MUNICIPIO_RESIDENCIA  ... Q024  Q025 NU_NOTA_TOTAL
# 0  190001004661    2019                  1506138  ...    B     B        2288.9
# 1  190001004674    2019                  1504208  ...    A     B        1184.6
# 2  190001004722    2019                  1501402  ...    A     B        2350.5
# 3  190001004735    2019                  1507300  ...    A     B        2555.7
# 4  190001004776    2019                  1500800  ...    A     B        2803.5
#
# [5 rows x 137 columns]

# %%
renda_ordenada = df['Q006'].unique()
renda_ordenada.sort()

plt.figure(figsize=(10,6))
plt.title("Notas totais por renda familiar")
sns.boxplot(x = 'Q006', y = 'NU_NOTA_TOTAL', data = df, order = renda_ordenada)

# %% [markdown]
# ## Desafio: Função para plot de notas

# %%
renda_ordenada = df['Q006'].unique()
renda_ordenada.sort()

def plotarNotasRenda(parametro):
    plt.figure(figsize=(10,6))
    plt.title("Notas de {} por renda familiar".format(parametro))
    sns.boxplot(x = 'Q006', y = parametro, data = df, order = renda_ordenada)

# %%
plotarNotasRenda('NU_NOTA_REDACAO')

# %% [markdown]
# ## Desafio: Verificar zerados e eliminados por falta

# %%
zerados = df.query('NU_NOTA_TOTAL == 0')['NU_IDADE']

zerados.hist(bins=20, figsize = (12,8), color ='midnightblue')
plt.title('Número de zerados por Idade', fontsize='xx-large')
plt.xlabel('Idades', fontsize = 12)
plt.ylabel('Participantes',fontsize=12)
# Out:
# Text(0, 0.5, 'Participantes')

# %%
presencas = ['TP_PRESENCA_CN','TP_PRESENCA_CH','TP_PRESENCA_LC','TP_PRESENCA_MT']

df.query('NU_NOTA_TOTAL == 0')[presencas].hist(bins=20, figsize = (12,8), color ='midnightblue')

#Todos os participantes que zeraram faltaram
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fcac4b21cf8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fcac4742a58>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fcac46f7cc0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fcac46aaf28>]],
#       dtype=object)

# %%
DadosSemNotasZero = df.query('NU_NOTA_TOTAL != 0')
DadosSemNotasZero.head()
# Out:
#    NU_INSCRICAO  NU_ANO  CO_MUNICIPIO_RESIDENCIA  ... Q024  Q025 NU_NOTA_TOTAL
# 0  190001004661    2019                  1506138  ...    B     B        2288.9
# 1  190001004674    2019                  1504208  ...    A     B        1184.6
# 2  190001004722    2019                  1501402  ...    A     B        2350.5
# 3  190001004735    2019                  1507300  ...    A     B        2555.7
# 4  190001004776    2019                  1500800  ...    A     B        2803.5
#
# [5 rows x 137 columns]

# %%
renda_ordenada = df['Q006'].unique()
renda_ordenada.sort()

plt.figure(figsize=(10,6))
plt.title("Notas totais por renda familiar (Retirados valores zero)")
sns.boxplot(x = 'Q006', y = 'NU_NOTA_TOTAL', data = DadosSemNotasZero, order = renda_ordenada)

# %%
plt.figure(figsize=(15,7))
plt.title("Notas totais por renda familiar e relação com treineiros (Retirados valores zero)")
sns.boxplot(x = 'Q006', y = 'NU_NOTA_TOTAL', data = DadosSemNotasZero, order = renda_ordenada, hue = 'IN_TREINEIRO')

# %% [markdown]
# ## Desafio: Proporção de treineiros por classe Social

# %%
df.query("IN_TREINEIRO==1")['Q006'].value_counts()
# Out:
# B    3027
# C    2567
# E    1267
# D    1199
# G    1057
# H     965
# F     855
# I     713
# A     596
# Q     520
# J     471
# N     436
# O     389
# P     380
# K     342
# M     310
# L     307
# Name: Q006, dtype: int64

# %%
numTreineiros = df.query("IN_TREINEIRO == 1")['Q006']

numTreineiros.hist(bins=20, figsize = (12,8), label = 'Treineiros', color = 'skyblue') 

plt.title('Proporção de treineiros no ENEM por classe Social', fontsize='xx-large')
plt.xlabel("Classes Sociais", fontsize= 12)
plt.ylabel("Número de treineiros", fontsize= 12)
# Out:
# Text(0, 0.5, 'Número de treineiros')

# %% [markdown]
# ## Desafio: Relação Notas x Acesso a internet (Questão 25)

# %%
#A = Sem acesso
#B = Com acesso

renda_ordenada = df['Q006'].unique()
renda_ordenada.sort()

plt.figure(figsize=(10,6))
plt.title("Notas totais no ENEM por acesso a internet (Retirados valores zero)",  fontsize='xx-large')
sns.boxplot(x = 'Q025', y = 'NU_NOTA_TOTAL', data = DadosSemNotasZero)

plt.xlabel("Acesso a internet", fontsize= 12)
plt.ylabel("Número de canditados", fontsize= 12)
# Out:
# Text(0, 0.5, 'Número de canditados')

# %% [markdown]
# ## Correlação de notas

# %%
plt.figure(figsize=(12,8))
sns.histplot(DadosSemNotasZero, x = 'NU_NOTA_TOTAL')
plt.title("Notas totais no ENEM (Retirados valores zero)",  fontsize='xx-large')
# Out:
# Text(0.5, 1.0, 'Notas totais no ENEM (Retirados valores zero)')

# %%
plt.figure(figsize=(12,8))
sns.histplot(DadosSemNotasZero, x = 'NU_NOTA_TOTAL', hue="Q025", kde=True)
plt.title("Comparação de notas totais com histograma de acesso a internet",  fontsize='xx-large')
# Out:
# Text(0.5, 1.0, 'Comparação de notas totais com histograma de acesso a internet')

# %%
plt.figure(figsize=(12,8))
sns.histplot(DadosSemNotasZero, x = 'NU_NOTA_TOTAL', hue="Q025", kde=True, stat='density', cumulative=True)
plt.title("Comparação de Quantis",  fontsize='xx-large')
# Out:
# Text(0.5, 1.0, 'Comparação de Quantis')

# %%
plt.figure(figsize=(12,12))
sns.scatterplot(data = DadosSemNotasZero, x='NU_NOTA_MT', y='NU_NOTA_LC')
#Igualando eixos
plt.xlim((-50, 1050))
plt.ylim((-50, 1050))
plt.title("Relação entre notas de Matemática e Linguagens e Códigos",  fontsize='xx-large')
# Out:
# Text(0.5, 1.0, 'Relação entre notas de Matemática e Linguagens e Códigos')

# %%
sns.pairplot(DadosSemNotasZero[notas])

# %%
correlacao = DadosSemNotasZero[notas].corr()
correlacao
# Out:
#                  NU_NOTA_REDACAO  NU_NOTA_CN  ...  NU_NOTA_MT  NU_NOTA_LC
# NU_NOTA_REDACAO         1.000000    0.504740  ...    0.493046    0.535797
# NU_NOTA_CN              0.504740    1.000000  ...    0.649527    0.641624
# NU_NOTA_CH              0.528338    0.668979  ...    0.610332    0.744170
# NU_NOTA_MT              0.493046    0.649527  ...    1.000000    0.587710
# NU_NOTA_LC              0.535797    0.641624  ...    0.587710    1.000000
#
# [5 rows x 5 columns]

# %%
plt.figure(figsize=(12,8))
sns.heatmap(correlacao, cmap='Blues', center=0, annot=True)

# %%
import numpy as np

plt.figure(figsize=(12,8))
mask = np.triu(np.ones_like(correlacao, dtype=bool))
cmap = 'Blues'
sns.heatmap(correlacao, mask=mask, cmap=cmap, center=0, annot=True)

# %% [markdown]
# ## Machine Learning

# %%
provas_entrada = ['NU_NOTA_CH','NU_NOTA_LC','NU_NOTA_CN','NU_NOTA_REDACAO']
provas_saida = 'NU_NOTA_MT'

DadosSemNotasZero = DadosSemNotasZero[notas].dropna()

notas_entrada = DadosSemNotasZero[provas_entrada]
notas_saida = DadosSemNotasZero[provas_saida]

# %%
x = notas_entrada
y = notas_saida

# %%
from sklearn.model_selection import train_test_split

seed = 4321

x_treino, x_teste, y_treino, y_teste = train_test_split(x, y, test_size = 0.25, random_state = seed)

# %%
x_treino.head()
# Out:
#         NU_NOTA_CH  NU_NOTA_LC  NU_NOTA_CN  NU_NOTA_REDACAO
# 90200        567.7       523.2       542.7            660.0
# 12375        497.1       423.0       445.2            580.0
# 46320        494.0       528.5       454.0            520.0
# 111208       561.9       572.7       385.8            640.0
# 75943        686.5       646.5       625.7            900.0

# %%
from sklearn.svm import LinearSVR

modelo = LinearSVR(random_state=seed)

modelo.fit(x_treino, y_treino)
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# LinearSVR(C=1.0, dual=True, epsilon=0.0, fit_intercept=True,
#           intercept_scaling=1.0, loss='epsilon_insensitive', max_iter=1000,
#           random_state=4321, tol=0.0001, verbose=0)

# %%
predicoes_matematica = modelo.predict(x_teste)

# %%
y_teste[:5]
# Out:
# 114991    459.7
# 104685    617.2
# 91028     520.0
# 115802    703.8
# 93303     627.1
# Name: NU_NOTA_MT, dtype: float64

# %%
plt.figure(figsize=(12,12))
sns.scatterplot(x= predicoes_matematica, y = y_teste)
plt.xlim((-50, 1050))
plt.ylim((-50, 1050))
# Out:
# (-50.0, 1050.0)

# %%
plt.figure(figsize=(12,12))
sns.scatterplot(x= y_teste, y = y_teste - predicoes_matematica)
plt.xlim((-50, 1050))
plt.ylim((-50, 1050))
plt.title("Taxa de erros")
# Out:
# Text(0.5, 1.0, 'Taxa de erros')

# %%
resultados = pd.DataFrame()
resultados["Real"] = y_teste
resultados["Previsao"] = predicoes_matematica
resultados["Diferenca"] = (resultados['Real'] - resultados['Previsao'])
resultados["Quadrado da Diferenca"] = (resultados['Real'] - resultados['Previsao'])**2
resultados
# Out:
#          Real    Previsao   Diferenca  Quadrado da Diferenca
# 114991  459.7  564.486105 -104.786105           10980.127878
# 104685  617.2  628.305027  -11.105027             123.321625
# 91028   520.0  509.980986   10.019014             100.380650
# 115802  703.8  593.681144  110.118856           12126.162420
# 93303   627.1  579.784588   47.315412            2238.748252
# ...       ...         ...         ...                    ...
# 81393   688.6  626.291851   62.308149            3882.305380
# 40159   479.1  652.313922 -173.213922           30003.062777
# 64083   501.4  607.787172 -106.387172           11318.230438
# 84661   772.5  734.227663   38.272337            1464.771772
# 79106   369.0  466.919690  -97.919690            9588.265665
#
# [23135 rows x 4 columns]

# %%
resultados['Quadrado da Diferenca'].mean()
# Out:
# 6604.415306219529

# %%
from sklearn.metrics import mean_squared_error

mean_squared_error(y_teste, predicoes_matematica) #predicoes da SVM
# Out:
# 6604.41530621957

# %%
from sklearn.dummy import DummyRegressor

modelo_dummy = DummyRegressor()
modelo_dummy.fit(x_treino, y_treino)
dummy_predicoes = modelo_dummy.predict(x_teste)

# %%
mean_squared_error(y_teste, dummy_predicoes)
# Out:
# 12063.645588509502

# %% [markdown]
# ## Validação de modelo

# %%
from sklearn.svm import LinearSVR

modelo = LinearSVR(random_state=seed)

modelo.fit(x_treino, y_treino)

predicoes_matematica = modelo.predict(x_teste)

mean_squared_error(y_teste, predicoes_matematica)
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# 6604.41530621957

# %%
from sklearn.tree import DecisionTreeRegressor

x_treino, x_teste, y_treino, y_teste = train_test_split(x, y, test_size=0.25)
modeloArvore = DecisionTreeRegressor(max_depth = 3)
modeloArvore.fit(x_treino, y_treino)
predicoesModeloArvore = modeloArvore.predict(x_teste)
mean_squared_error(y_teste, predicoesModeloArvore)
# Out:
# 6135.836126888446

# %%
from sklearn.model_selection import cross_validate
modeloArvore = DecisionTreeRegressor(max_depth = 2)
result = cross_validate(modeloArvore, x, y, scoring='neg_mean_squared_error')
media = (result['test_score']*-1).mean() #Tornando os valores positivos
desviopadrao = (result['test_score']*-1).std()
limInferior = media - (desviopadrao * 2 )
limSuperior = media + (desviopadrao * 2 )

print(f"Intervalo de confiamça: {limInferior} - {limSuperior}") #95% das previsões dentro desses limites
# Out:
# Intervalo de confiamça: 6162.377051503182 - 6950.632947334635

# %%
media
# Out:
# 6556.5049994189085

# %%
desviopadrao
# Out:
# 197.06397395785953

# %%
def calculaMse(resultados):
  media = (result['test_score']*-1).mean() #Tornando os valores positivos
  desviopadrao = (result['test_score']*-1).std()
  limInferior = media - (desviopadrao * 2 )
  limSuperior = media + (desviopadrao * 2 ) 
  print(f"Intervalo de confiança: {limInferior} - {limSuperior}") #95% das previsões dentro desses limites

calculaMse(result)
# Out:
# Intervalo de confiança: 5533.563736266461 - 6594.205962103165

# %%
from sklearn.model_selection import KFold

partes = KFold(n_splits = 10, shuffle=True)
modeloArvore = DecisionTreeRegressor(max_depth = 3)
result = cross_validate(modeloArvore, x, y, cv = partes, scoring='neg_mean_squared_error')

calculaMse(result)
# Out:
# Intervalo de confiança: 5895.908028796577 - 6222.005826462466

# %%
def regressor_arvore(nivel):
    SEED= 1232
    np.random.seed(SEED)
    partes = KFold(n_splits = 10, shuffle=True)
    modelo_arvore = DecisionTreeRegressor(max_depth=nivel)
    resultados = cross_validate(modelo_arvore, x, y, cv= partes, scoring="neg_mean_squared_error", return_train_score=True)
    print(f"Treino = {(resultados['train_score']*-1).mean()}|Teste = {(resultados['test_score']*-1).mean()}")

regressor_arvore(4)
# Out:
# Treino = 5760.834451245899|Teste = 5815.707286597402

# %%
for i in range(1,21):
    regressor_arvore(i)
# Out:
# Treino = 7844.952652412207|Teste = 7857.871770206351
# Treino = 6527.783475408351|Teste = 6556.886287657656
# Treino = 6021.275229419075|Teste = 6054.767567442072
# Treino = 5760.834451245899|Teste = 5815.707286597402
# Treino = 5598.158955426787|Teste = 5675.196789060744
# Treino = 5469.677369145869|Teste = 5593.304363812442
# Treino = 5369.458309852721|Teste = 5541.646599457925
# Treino = 5276.16965707928|Teste = 5542.053091078966
# Treino = 5166.713159932668|Teste = 5608.390265709719
# Treino = 5022.598049115693|Teste = 5761.4934268457555
# Treino = 4833.560706021637|Teste = 5955.331403579403
# Treino = 4598.125022484774|Teste = 6217.553668629227
# Treino = 4316.3791662866815|Teste = 6521.403312280134
# Treino = 4000.6209880837496|Teste = 6853.984106997142
# Treino = 3655.8197526274853|Teste = 7224.863053512405
# Treino = 3295.832684540846|Teste = 7636.168819779455
# Treino = 2931.7212612043877|Teste = 8071.851486256819
# Treino = 2575.59534021339|Teste = 8452.126711298857
# Treino = 2233.574203221172|Teste = 8833.470443567128
# Treino = 1913.8727239705706|Teste = 9137.12202398264
